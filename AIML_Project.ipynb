# %% [markdown]
# <a href="https://colab.research.google.com/github/8880-lakshmi/AIML-PROJECT/blob/main/AIML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# student score card
df=pd.read_csv('/content/Student score card.csv')
print(df.head())
print(df.shape)
print(df.tail())
# Out:
#            Name  Roll.no  Physics  Chemistry  Maths  Hindi  English  Total  \
# 0   Ayush Kumar    12100       66         58     85     81       70    360
# 1   Aryan Kumar    12101       76         55     78     59       60    328
# 2  Ayansh Kumar    12102       75         59     76     88       65    363
# 3  Aditya Kumar    12103       68         71     69     55       75    338
# 4       Abhiraj    12104       81         77     68     77       81    384
#
#    Percentage  Rank
# 0        72.0     7
# 1        65.6     9
# 2        72.6     6
# 3        67.6     8
# 4        76.8     1
# (9, 10)
#             Name  Roll.no  Physics  Chemistry  Maths  Hindi  English  Total  \
# 4        Abhiraj    12104       81         77     68     77       81    384
# 5   Ankush Kumar    12105       85         78     58     66       87    374
# 6  Rajnish Kumar    12106       79         68     80     76       77    380
# ...

# %%
score=np.array(df)
print(score)
# Out:
# [['Ayush Kumar' 12100 66 58 85 81 70 360 72.0 7]
#  ['Aryan Kumar' 12101 76 55 78 59 60 328 65.6 9]
#  ['Ayansh Kumar' 12102 75 59 76 88 65 363 72.6 6]
#  ['Aditya Kumar' 12103 68 71 69 55 75 338 67.6 8]
#  ['Abhiraj' 12104 81 77 68 77 81 384 76.8 1]
#  ['Ankush Kumar' 12105 85 78 58 66 87 374 74.8 5]
#  ['Rajnish Kumar' 12106 79 68 80 76 77 380 76.0 2]
#  ['Shivam Kumar' 12107 71 67 81 78 78 375 75.0 4]
#  ['Shloak' 12108 69 72 75 79 81 376 75.2 3]]

# %%
plt.hist(df[['Maths','Physics','Chemistry','English','Hindi']])
# Out:
# (array([[1., 0., 0., 1., 1., 0., 3., 2., 0., 1.],
#         [0., 0., 0., 2., 2., 0., 2., 2., 0., 1.],
#         [2., 1., 0., 2., 1., 1., 2., 0., 0., 0.],
#         [0., 1., 0., 1., 1., 0., 3., 2., 0., 1.],
#         [1., 1., 0., 1., 0., 0., 3., 2., 0., 1.]]),
#  array([55. , 58.3, 61.6, 64.9, 68.2, 71.5, 74.8, 78.1, 81.4, 84.7, 88. ]),
#  <a list of 5 BarContainer objects>)

# %%
score=np.mean(df[['Maths','Physics','Chemistry','Hindi','English']])
print(score)
score=np.std(df[['Maths','Physics','Chemistry','Hindi','English']])
print(score)
score=np.median(df[['Maths','Physics','Chemistry','Hindi','English']])
print(score)
# Out:
# 72.84444444444445
# Maths         7.761889
# Physics       6.075655
# Chemistry     7.828407
# Hindi        10.239116
# English       8.020037
# dtype: float64
# 75.0
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:3800: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
